# %%
import pandas as pd
import numpy as np

dtypes = np.dtype([
          ('a', np.datetime64),
          ('b', int),
          ('c', int),
          ('d', int),
          ])
# note: I am aware that it is not initialized with 10 rows,
# but I had an issue when using a list or tuple with rows
data = np.empty(0, dtype=dtypes)
df = pd.DataFrame(data)
df['a'] = pd.date_range('2018-01', periods=36, freq='MS')
df['b'] = np.random.randint(0, 9, 36)
df['c'] = np.random.randint(0, 9, 36)
df['d'] = df["b"] - df["c"]
df1 = df.iloc[0:12]
df2 = df.iloc[12:24]
df3 = df.iloc[24:]
# Out:
#             a  b  c  d
# 24 2020-01-01  3  7 -4
# 25 2020-02-01  4  4  0
# 26 2020-03-01  0  7 -7
# 27 2020-04-01  8  6  2
# 28 2020-05-01  1  2 -1
# 29 2020-06-01  6  4  2
# 30 2020-07-01  1  2 -1
# 31 2020-08-01  3  6 -3
# 32 2020-09-01  0  1 -1
# 33 2020-10-01  0  6 -6
# 34 2020-11-01  1  5 -4
# 35 2020-12-01  8  6  2

# %%
import random 
import numpy as np
import keras 

#Generate some training data
x_train = []
y_train = []
for t_in_celcius in random.sample(range(-500, 500), 1000):
  x_train.append(t_in_celcius)
  y_train.append(t_in_celcius * 1.8 + 32)
X = np.array(x_train)
y = np.array(y_train)

#Fit model to data 
model = Sequential()
model.add(Dense(1, kernel_initializer='uniform', input_shape=(1,)))
 
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.05), loss='mse')
model.fit(X, y, batch_size=1, epochs=20, verbose=1, validation_split=0.2)

# Check if model is good
print(model.get_weights())
print(model.predict(np.array([100]), batch_size=1))
# Out:
# Train on 800 samples, validate on 200 samples
# Epoch 1/20
# 800/800 [==============================] - 1s 1ms/step - loss: 8439.2147 - val_loss: 525.4762
# Epoch 2/20
# 800/800 [==============================] - 1s 924us/step - loss: 323.5527 - val_loss: 128.6235
# Epoch 3/20
# 800/800 [==============================] - 1s 888us/step - loss: 61.4036 - val_loss: 12.8208
# Epoch 4/20
# 800/800 [==============================] - 1s 868us/step - loss: 4.8401 - val_loss: 0.9354
# Epoch 5/20
# 740/800 [==========================>...] - ETA: 0s - loss: 0.1397
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-bd1a5d890f9b> in <module>()
#      17
#      18 model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.05), loss='mse')
# ---> 19 model.fit(X, y, batch_size=1, epochs=20, verbose=1, validation_split=0.2)
#      20
#      21 # Check if model is good
#
# ...
